# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiX27/ds2002-fa26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
# TODO: fix so this prints a greeting
greeting = "Hello!"   # create a variable called greeting and set it equal to the string "Hello!"
print(greeting)
# Out:
# Hello!

# %% [markdown]
# **What was wrong:** The name *greeting* is not defined as a variable is not written as a string with quotation marks, so the code runs into an error. I created a variable called *greeting* and set it equal to the string "Hello!" before the print line. Then, print(greeting) will display "Hello!" as the output.

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
# TODO: fix so total is the number 30
total = 10 + 20       # remove the quotation marks around 10 to make it an integer (int)
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** We can not add two different variable types together in this case. In the code, '10' is a string, but 20 is an integer, so a string (str) and an integer (int) cannot be added together. Thus, the code runs into an error. If we write total = '10' + '20', the output will be '1020', which is also a string. It does not print out 30 because the code is combining two strings together instead of adding two integers. I removed the quotation marks around 10 to make it an integer (int). Then, print(total) will display 30 as an integer because the code is adding two integers together correctly.

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat']

# TODO: print the LAST item, and do it in a way that still works if someone adds a fourth item tomorrow
print(items[-1])     # Change the index from 3 to -1
# Out:
# hat

# %% [markdown]
# **What was wrong:** With the original index 3, the code is trying to look for the fourth item in the list because Python starts counting indexes from 0. In this list, 'burger' is at index 0, 'poncho' is at index 1, and 'hat' is at index 2. The list "items" does not have an item at index 3, so the code runs into an arror. I changed the index from 3 to -1, which means counting from the end of the list. When I run print(items[-1]), it will always print the last item, even if someone adds a fourth item tomorrow or adds more items to the list.

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)   # change 2 to len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** With the original code, average = sum(nums) / 2 is incorrect because 2 is not the number of values in the "nums" list. So, the code prints the wrong average. To calculate the average, we need to add all the numbers in the "nums" list and then divide the sum by the length of the list, which is 4 in this case. I changed 2 to len(nums) so that the code correctly uses the number of values in the list. I used len(nums) instead of directly writing 4 because I do not need to count how many numbers are in the list myself, especially if many numbers are added later. The correct code is average = sum(nums) / len(nums), and the output should be 5.0.

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b'], 'price': [1, 2]})    # delete 3 from 'price' list
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2

# %% [markdown]
# **What was wrong:** With the original code, there are two items in the 'item' list, while there are three values in the 'price' list. The two arrays do not have the same number of entries, so the code runs into an error. In order for the code to run and create a table, a DataFrame requires all columns to have the same number of entries. I deleted the third value, 3, from the 'price' list so that both columns have two entries.

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# %%
# TODO: rewrite these two lines so re-running cannot change the answer
# sales['units'] = sales['units'] * 1.05
# print('total units:', round(sales['units'].sum(), 2))

work = sales.copy()     # make a copy of sales and store in work
work['units_with_fee'] = work['units'] * 1.05
print('total units:', round(work['units_with_fee'].sum(), 2))
# Out:
# total units: 3213.0

# %%
# Proof — this must print the same number three times
for attempt in range(3):
    # TODO: rebuild from the raw values and print your total
    work = sales.copy()
    work['units_with_fee'] = work['units'] * 1.05
    print('total units:', round(work['units_with_fee'].sum(), 2))
# Out:
# total units: 3213.0
# total units: 3213.0
# total units: 3213.0

# %% [markdown]
# **What was wrong:** When I put the line that creates a DataFrame and stores it in the variable "sales" and the line that calculates the 5% service fee in the same  sell, every time the cell runs, Python resets sales['units'] to the original value, 1450 and 1610, and then multiplies them by 1.05, so the total stays the same. If I split these two lines into two separate cells, every time I rerun the second cell, Python does not reset "sales", so it used the already-changed values from the previous run, and the total changes or compounds.

# %% [markdown]
# In order to make rerunning the code not change the answer, I used work = sales.copy() to make a copy of the "sales" DataFrame and store it in "work", so that I can make changes to "work" DataFrame without changing "sale" DataFrame. Then, I created a new column called 'unites_with_fee' in "work" by multiplying each value in the 'units' column by 1.05. Next, I used .sum() to add all the values in the 'units_with_fee' column, rounded the total to 2 decimal places, and printed the total.

# %% [markdown]
# In the third cell,  I used a for loop to repeat the code three times because range (3) gives three values: 0, 1, and 2. I  also rebuilt the "work" DataFrame from the original "sales" DataFrame and copied all the code from the second cell into the loop. The code should print the same total, 3213.0, three times.

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''

# TODO: replace this with a lookup + fallback that works anywhere
# orders = pd.read_csv('/Users/someone/Desktop/gameday_orders.csv')

def load_csv(filename, sample=SAMPLE):
    if os.path.exists(filename):
      print('You used the real file.')
      return pd.read_csv(filename)  # read the actual CSV
    else:
      print('You fell back to the sample.')
      return pd.read_csv(StringIO(sample))  # read the sample

orders = load_csv('gameday_orders.csv')
orders
# Out:
# You fell back to the sample.
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** When I directly ran the original code, it gaves me a FileNotFoundError. The original code used a file path from someone else' Desktop, so Python could not find the CSV file in my notebook environment. I created the load_csv function with filename, which is the name of the CSV file I want to load, and sample=SAMPLE, which is the fallback sample data if the file does not exist. Then, I used if/else statements to check whether the file exists or not. If the file exists, using ifs os.path.exists(filename), the codes prints 'You used the real file.', reads the CSV file, and returns the DataFrame. If the file does not exist, the code prints 'You fell back to the sample.' read the sample, and returns the sample DataFrame. Finally, for the "orders" variable, I replaced pd.read_csv() with load_csv to run the function. I also change '/Users/someone/Desktop/gameday_orders.csv' to 'gameday_orders.csv' so that the code checks the current notebook environment instead of someone else's Desktop. In this case, 'gameday_orders.csv' does not exist, , so the code prints the 'You fell back to the sample.', reads the sample, and returns the sample DataFrame, and then displays it through "order".

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
assert isinstance(greeting, str) and greeting != ''
assert total == 30
assert items[-1] == 'hat'
assert average == 5
assert len(df) == 2
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/ShiX27/ds2002-fa26'
commit_sha = '432ab0d'
notebook_link = 'https://github.com/ShiX27/ds2002-fa26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb'
ran_restart_and_run_all = True   # TODO: set True after you actually do it

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# PASS - commit hash looks like a hash
# PASS - notebook link filled in
# PASS - restarted and ran all
#
# Ready to submit: True

# %% [markdown]
# ### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# _your answer here_

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
# stretch
